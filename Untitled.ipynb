# %%
import pandas as pd
import os
from sqlalchemy import create_engine
from config import db_password
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import extract
from sqlalchemy import create_engine, func
import re

# %%
# Files to load
L_Stops_df = pd.read_csv("CTA_list_of_L_stops.csv")
Ridership_df = pd.read_csv("CTA_ridership_daily_totals.csv")

# %%
L_Stops_df
# Out:
#      STOP_ID DIRECTION_ID                        STOP_NAME  \
# 0      30162            W         18th (54th/Cermak-bound)
# 1      30161            E                18th (Loop-bound)
# 2      30022            N         35th/Archer (Loop-bound)
# 3      30023            S       35th/Archer (Midway-bound)
# 4      30214            S  35-Bronzeville-IIT (63rd-bound)
# ..       ...          ...                              ...
# 295    30105            N            Wilson (Howard-bound)
# 296    30239            N           Addison (O'Hare-bound)
# 297    30106            S              Wilson (95th-bound)
# 298    30383            N   Washington/Wabash (Outer Loop)
# 299    30385            S              Wilson (Loop-bound)
#
#              STATION_NAME                           STATION_DESCRIPTIVE_NAME  \
# 0                    18th                                   18th (Pink Line)
# 1                    18th                                   18th (Pink Line)
# ...

# %%
Ridership_df
# Out:
#          station_id        stationname        date daytype  rides
# 0             41280     Jefferson Park  12/22/2017       W   6104
# 1             41000   Cermak-Chinatown  12/18/2017       W   3636
# 2             40280       Central-Lake  12/02/2017       A   1270
# 3             40140    Dempster-Skokie  12/19/2017       W   1759
# 4             40690           Dempster  12/03/2017       U    499
# ...             ...                ...         ...     ...    ...
# 1036758       41700  Washington/Wabash  11/26/2020       U    601
# 1036759       41700  Washington/Wabash  11/27/2020       W   2093
# 1036760       41700  Washington/Wabash  11/28/2020       A   1782
# 1036761       41700  Washington/Wabash  11/29/2020       U   1222
# 1036762       41700  Washington/Wabash  11/30/2020       W   2041
#
# [1036763 rows x 5 columns]

# %%
#station_bools =L_Stops_df[['MAP_ID','ADA','RED','BLUE','G','BRN','P','Pexp','Y','Pnk','O']].groupby('MAP_ID').any()
#L_Stops_df = L_Stops_df.drop(['STOP_ID', 'DIRECTION_ID', 'STOP_NAME', \
#'ADA','RED','BLUE','G','BRN','P','Pexp','Y','Pnk','O'], axis=1) \
#    .merge(station_bools, how='left', left_on='MAP_ID', \
#right_index=True).drop_duplicates()

# %%
#L_Stops_df['STATION_NAME'].isin(Ridership_df['stationname']).value_counts()
L_Stops_df["AnyLine"] = L_Stops_df[['ADA','RED','BLUE','G','BRN','P','Pexp','Y','Pnk','O']].any(axis='columns')
L_Stops_df
# Out:
#      STOP_ID DIRECTION_ID                        STOP_NAME  \
# 0      30162            W         18th (54th/Cermak-bound)
# 1      30161            E                18th (Loop-bound)
# 2      30022            N         35th/Archer (Loop-bound)
# 3      30023            S       35th/Archer (Midway-bound)
# 4      30214            S  35-Bronzeville-IIT (63rd-bound)
# ..       ...          ...                              ...
# 295    30105            N            Wilson (Howard-bound)
# 296    30239            N           Addison (O'Hare-bound)
# 297    30106            S              Wilson (95th-bound)
# 298    30383            N   Washington/Wabash (Outer Loop)
# 299    30385            S              Wilson (Loop-bound)
#
#              STATION_NAME                           STATION_DESCRIPTIVE_NAME  \
# 0                    18th                                   18th (Pink Line)
# 1                    18th                                   18th (Pink Line)
# ...

# %%
L_Stops_df = L_Stops_df.drop(['STOP_ID', 'DIRECTION_ID', 'STOP_NAME', \
'ADA','RED','BLUE','G','BRN','P','Pexp','Y','Pnk','O'], axis=1)

# %%
L_Stops_df = L_Stops_df.drop_duplicates()

# %%
L_Stops_df[['latitude','longitude']] = \
L_Stops_df['Location'].str.replace('\(|\)','',
regex=True).str.split(',',expand=True).apply(pd.to_numeric)

# %%
df = pd.merge(Ridership_df, L_Stops_df, how='left', left_on='station_id', \
right_on='MAP_ID')

# %%
df['south_side'] = df['latitude'] < 41.881

# %%
df.groupby(['south_side'])['rides'].mean()
#mean = df[['rides']].groupby('south_side').mean()
# Out:
# south_side
# False    3613.003287
# True     2710.223723
# Name: rides, dtype: float64

# %%
df['year'] = pd.DatetimeIndex(df['date']).year

# %%
rides_by_sides = df[['year','south_side','rides']] \
    .groupby(['year','south_side']).mean() \
    .reset_index() \
    .pivot(index='year',columns='south_side',values='rides')
rides_by_sides.columns = ['north','south']
(rides_by_sides['north'] - rides_by_sides['south']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df = df.drop(['MAP_ID', 'Location'], axis=1)

# %%
df = df.drop(['STATION_NAME'], axis=1)

# %%
df
# Out:
#          station_id        stationname        date daytype  rides  \
# 0             41280     Jefferson Park  12/22/2017       W   6104
# 1             41000   Cermak-Chinatown  12/18/2017       W   3636
# 2             40280       Central-Lake  12/02/2017       A   1270
# 3             40140    Dempster-Skokie  12/19/2017       W   1759
# 4             40690           Dempster  12/03/2017       U    499
# ...             ...                ...         ...     ...    ...
# 1044034       41700  Washington/Wabash  11/26/2020       U    601
# 1044035       41700  Washington/Wabash  11/27/2020       W   2093
# 1044036       41700  Washington/Wabash  11/28/2020       A   1782
# 1044037       41700  Washington/Wabash  11/29/2020       U   1222
# 1044038       41700  Washington/Wabash  11/30/2020       W   2041
#
#                                   STATION_DESCRIPTIVE_NAME AnyLine   latitude  \
# 0                               Jefferson Park (Blue Line)    True  41.970634
# ...

# %%
#db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/CTA_DB"

# %%
#engine = create_engine(db_string)

# %%
#df.to_sql(name='Stations', con=engine)

# %%
# Path to sqlite, THIS MAY NOT MATCH YOUR PATH
database_path = "Census_Data.sqlite"

# Create an engine that can talk to the database
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()
Base = automap_base()
Base.prepare(engine, reflect=True)
conn = engine.connect()
Base.classes.keys()
# Out:
# []

# %%
census_data_df = pd.read_sql("SELECT * FROM Census_Data", conn)

# %%
census_data_df
# Out:
#                  CityState               city state  Population  \
# 0              HOUSTON, TX            HOUSTON    TX     3061887
# 1              CHICAGO, IL            CHICAGO    IL     2702091
# 2             BROOKLYN, NY           BROOKLYN    NY     2595259
# 3          LOS ANGELES, CA        LOS ANGELES    CA     2426413
# 4                MIAMI, FL              MIAMI    FL     1820704
# ..                     ...                ...   ...         ...
# 994  ALTAMONTE SPRINGS, FL  ALTAMONTE SPRINGS    FL       56883
# 995        CHILLICOTHE, OH        CHILLICOTHE    OH       56783
# 996         FARMINGTON, NM         FARMINGTON    NM       56781
# 997          FAIRFIELD, CT          FAIRFIELD    CT       56704
# 998   DEARBORN HEIGHTS, MI   DEARBORN HEIGHTS    MI       56656
#
#      White Population  Black Population  Native American Population  \
# 0             1775897            684416                       11586
# ...

# %%
# Out:
# []

# %%
#results = session.query()

# %%
dracula_df = pd.read_csv('dracula.txt', sep='\n', header=None)
dracula_df.columns = ['text']

# %%
dracula_df
# Out:
#                                                     text
# 0                                                DRACULA
# 1                                                DRACULA
# 2                                                   _by_
# 3                                            Bram Stoker
# 4                               [Illustration: colophon]
# ...                                                  ...
# 10618  proofs of so wild a story. Van Helsing summed ...
# 10619                             our boy on his knee:--
# 10620  We want no proofs; we ask none to believe us! ...
# 10621                                   JONATHAN HARKER.
# 10622                                            THE END
#
# [10623 rows x 1 columns]

# %%
p = '(\w vampire\s+([^.-]+))'
dracula_df['text'].str.extractall(p, flags=re.I)[0].value_counts()
# Out:
# s Vampire is limit to the powers of man,                                                                                                   1
# e vampire in general, and of this one in particular                                                                                        1
# e vampire meant                                                                                                                            1
# y vampire sleep                                                                                                                            1
# e vampire coming in her face                                                                                                               1
# e vampire kind; we have sources of science; we are free to\r\nact and think; and the hours of the day and the night are ours equally       1
# ...
